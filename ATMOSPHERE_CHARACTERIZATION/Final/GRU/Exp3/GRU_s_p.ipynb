# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/pos-1m-clean/1M_pos_clean_data.npy

# %%
import matplotlib.pyplot as plt
import scipy as sp
import numpy as np
import pandas as pd

# %%
data = np.load('/kaggle/input/pos-1m-clean/1M_pos_clean_data.npy')
data.shape
# Out:
# (995978, 279)

# %%
test_ind = [1,10,100]
new_data = np.delete(data,test_ind,axis=0)
new_data.shape
# Out:
# (995975, 279)

# %%
train_data = new_data
new_spec = np.zeros_like(train_data[:,:273])
for i in range(len(train_data)):
    mean_sp = np.mean(train_data[i,:269])
    std_sp = np.std(train_data[i,:269])
    new_spec[i,:269] = (train_data[i,:269] - mean_sp) / std_sp
#     new_spec[i,269] = mean_sp
    new_spec[i,269] = std_sp
    new_spec[i,270] = train_data[i,269]   # rstar
    new_spec[i,271] = train_data[i,270]   # rplanet
    new_spec[i,272] = train_data[i,271]   # gp

new_spec.shape
# Out:
# (995975, 273)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchinfo import summary
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from torch.optim.lr_scheduler import ExponentialLR

class GRUModel(nn.Module):
    def __init__(self ):
        super(GRUModel, self).__init__()
        self.gru1 = nn.GRU(input_size=X_train.shape[1], hidden_size=64,num_layers=1,
                            bidirectional=False, batch_first=True)
        self.gru2 = nn.GRU(64, hidden_size=128, num_layers=1, 
                            bidirectional=False, batch_first=True)
        self.gru3 = nn.GRU(128, hidden_size=256, num_layers=1, 
                            bidirectional=False, batch_first=True)
        self.gru4 = nn.GRU(256, hidden_size=128, num_layers=1, 
                            bidirectional=False, batch_first=True)
        self.dense = nn.Linear(128, 7)
    
    def forward(self, x):
        x, _ = self.gru1(x)
        x, _ = self.gru2(x)
        x, _ = self.gru3(x)
        x, _ = self.gru4(x)
        x = self.dense(x)
        return x

# R^2 loss function
class R2Loss(nn.Module):
    def __init__(self):
        super(R2Loss, self).__init__()

    def forward(self, y_pred, y_true):
        ss_res = torch.sum(torch.square(y_true - y_pred))
        ss_tot = torch.sum(torch.square(y_true - torch.mean(y_true)))
        r2 = 1 - ss_res / ss_tot
        return r2

# %% [markdown]
# ## 10k Data

# %%
X = new_spec[:10000]
Y = new_data[:10000,272:]
X.shape, Y.shape

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
Y = scaler.fit_transform(Y)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.20, random_state = 42)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((8000, 273), (2000, 273), (8000, 7), (2000, 7))

# %%
initial_learning_rate = 1e-4
final_learning_rate = 1e-6
epochs = 100
train_size = X_train.shape[0]
batch_size = 32
lr_decay_factor = (final_learning_rate / initial_learning_rate)**(1/epochs)
steps_per_epoch = int(train_size/batch_size)
lr_decay_factor, steps_per_epoch
# Out:
# (0.954992586021436, 250)

# %%
net_10k = GRUModel()

input_size = (1,X_train.shape[1])
summary(net_10k, input_size)
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# GRUModel                                 [1, 7]                    --
# ├─GRU: 1-1                               [1, 64]                   65,088
# ├─GRU: 1-2                               [1, 128]                  74,496
# ├─GRU: 1-3                               [1, 256]                  296,448
# ├─GRU: 1-4                               [1, 128]                  148,224
# ├─Linear: 1-5                            [1, 7]                    903
# ==========================================================================================
# Total params: 585,159
# Trainable params: 585,159
# Non-trainable params: 0
# Total mult-adds (M): 108.57
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 2.34
# Estimated Total Size (MB): 2.35
# ==========================================================================================

# %%
data = X_train
labels = y_train


data = torch.from_numpy(data).float()
labels = torch.from_numpy(labels).float()


trainset = torch.utils.data.TensorDataset(data, labels)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=32, shuffle=True)


criterion = nn.MSELoss()
optimizer = optim.Adam(net_10k.parameters(), lr=0.0001)
scheduler = ExponentialLR(optimizer,gamma=lr_decay_factor)


device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Train the neural network

epochs = 100

net_10k.to(device)
losses = []
r2s = []
test_losses = []
test_r2s = []
cur_lrs =[]
for epoch in range(epochs):
    net_10k.train()
    running_loss = 0.0
    running_r2 = 0.0
    for i, data in enumerate(trainloader, 0):
        
        
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = net_10k(inputs)
        loss = criterion(outputs, labels)
        r2 = R2Loss()(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        running_r2 += r2.item()
    losses.append(running_loss / len(trainloader))
    r2s.append(running_r2 / len(trainloader))
#         print('Epoch %d loss: %.3f R^2: %.3f' % (epoch + 1, running_loss / len(trainloader), running_r2 / len(trainloader)))
    
    # Test the neural network on the test data
    test_data = X_test
    test_labels = y_test
    test_data = torch.from_numpy(test_data).float()
    test_labels = torch.from_numpy(test_labels).float()
    net_10k.eval()
    with torch.no_grad():
        test_data, test_labels = test_data.to(device), test_labels.to(device)
        test_outputs = net_10k(test_data)
        test_loss = criterion(test_outputs, test_labels)
        test_r2 = R2Loss()(test_outputs, test_labels)
        test_losses.append(test_loss.item())
        test_r2s.append(test_r2.item())
    current_lr = optimizer.param_groups[0]['lr']
    cur_lrs.append(current_lr)
    print('Epoch %d loss: %.3f R^2: %.3f test_loss: %.3f test_R^2: %.3f  ' % (epoch + 1, running_loss / len(trainloader), running_r2 / len(trainloader), test_loss, test_r2))    
    scheduler.step()
    
# plotting model loss    
plt.plot(losses,label='train_loss')
plt.plot(test_losses, label='test_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Model loss')
plt.legend()
plt.grid()
plt.show()
# plotting model r2 score
plt.plot(r2s, label='train_r2')
plt.plot(test_r2s, label='test_r2')
plt.xlabel('Epoch')
plt.ylabel('R^2')
plt.title('Model $R^{2}$ score')
plt.legend()
plt.grid()
plt.show()
# Out:
# Epoch 1 loss: 0.975 R^2: 0.019 test_loss: 0.860 test_R^2: 0.145
# Epoch 2 loss: 0.684 R^2: 0.313 test_loss: 0.534 test_R^2: 0.469
# Epoch 3 loss: 0.471 R^2: 0.527 test_loss: 0.442 test_R^2: 0.560
# Epoch 4 loss: 0.419 R^2: 0.579 test_loss: 0.404 test_R^2: 0.598
# Epoch 5 loss: 0.379 R^2: 0.619 test_loss: 0.373 test_R^2: 0.629
# Epoch 6 loss: 0.354 R^2: 0.643 test_loss: 0.347 test_R^2: 0.655
# Epoch 7 loss: 0.335 R^2: 0.663 test_loss: 0.330 test_R^2: 0.671
# Epoch 8 loss: 0.318 R^2: 0.680 test_loss: 0.315 test_R^2: 0.687
# Epoch 9 loss: 0.304 R^2: 0.694 test_loss: 0.307 test_R^2: 0.695
# Epoch 10 loss: 0.292 R^2: 0.706 test_loss: 0.291 test_R^2: 0.710
# Epoch 11 loss: 0.280 R^2: 0.718 test_loss: 0.289 test_R^2: 0.712
# Epoch 12 loss: 0.272 R^2: 0.726 test_loss: 0.276 test_R^2: 0.725
# Epoch 13 loss: 0.266 R^2: 0.732 test_loss: 0.271 test_R^2: 0.730
# Epoch 14 loss: 0.260 R^2: 0.738 test_loss: 0.264 test_R^2: 0.737
# Epoch 15 loss: 0.255 R^2: 0.744 test_loss: 0.262 test_R^2: 0.739
# Epoch 16 loss: 0.250 R^2: 0.749 test_loss: 0.259 test_R^2: 0.742
# Epoch 17 loss: 0.246 R^2: 0.752 test_loss: 0.253 test_R^2: 0.748
# Epoch 18 loss: 0.242 R^2: 0.756 test_loss: 0.251 test_R^2: 0.750
# Epoch 19 loss: 0.238 R^2: 0.761 test_loss: 0.247 test_R^2: 0.754
# Epoch 20 loss: 0.236 R^2: 0.763 test_loss: 0.245 test_R^2: 0.757
# Epoch 21 loss: 0.233 R^2: 0.766 test_loss: 0.246 test_R^2: 0.756
# Epoch 22 loss: 0.229 R^2: 0.769 test_loss: 0.236 test_R^2: 0.765
# Epoch 23 loss: 0.228 R^2: 0.771 test_loss: 0.236 test_R^2: 0.765
# Epoch 24 loss: 0.225 R^2: 0.773 test_loss: 0.233 test_R^2: 0.769
# Epoch 25 loss: 0.222 R^2: 0.777 test_loss: 0.233 test_R^2: 0.769
# Epoch 26 loss: 0.221 R^2: 0.778 test_loss: 0.229 test_R^2: 0.773
# Epoch 27 loss: 0.218 R^2: 0.780 test_loss: 0.227 test_R^2: 0.774
# Epoch 28 loss: 0.217 R^2: 0.781 test_loss: 0.227 test_R^2: 0.775
# Epoch 29 loss: 0.216 R^2: 0.783 test_loss: 0.225 test_R^2: 0.776
# Epoch 30 loss: 0.214 R^2: 0.785 test_loss: 0.226 test_R^2: 0.775
# Epoch 31 loss: 0.213 R^2: 0.785 test_loss: 0.222 test_R^2: 0.780
# Epoch 32 loss: 0.212 R^2: 0.787 test_loss: 0.220 test_R^2: 0.781
# Epoch 33 loss: 0.210 R^2: 0.789 test_loss: 0.219 test_R^2: 0.782
# Epoch 34 loss: 0.209 R^2: 0.790 test_loss: 0.218 test_R^2: 0.783
# Epoch 35 loss: 0.208 R^2: 0.790 test_loss: 0.218 test_R^2: 0.784
# Epoch 36 loss: 0.206 R^2: 0.793 test_loss: 0.216 test_R^2: 0.786
# Epoch 37 loss: 0.205 R^2: 0.794 test_loss: 0.214 test_R^2: 0.787
# Epoch 38 loss: 0.205 R^2: 0.794 test_loss: 0.214 test_R^2: 0.787
# Epoch 39 loss: 0.204 R^2: 0.795 test_loss: 0.214 test_R^2: 0.788
# Epoch 40 loss: 0.203 R^2: 0.796 test_loss: 0.211 test_R^2: 0.790
# Epoch 41 loss: 0.202 R^2: 0.797 test_loss: 0.211 test_R^2: 0.790
# Epoch 42 loss: 0.201 R^2: 0.798 test_loss: 0.211 test_R^2: 0.790
# Epoch 43 loss: 0.200 R^2: 0.798 test_loss: 0.210 test_R^2: 0.792
# Epoch 44 loss: 0.200 R^2: 0.799 test_loss: 0.210 test_R^2: 0.791
# Epoch 45 loss: 0.200 R^2: 0.799 test_loss: 0.208 test_R^2: 0.793
# Epoch 46 loss: 0.199 R^2: 0.800 test_loss: 0.208 test_R^2: 0.793
# Epoch 47 loss: 0.198 R^2: 0.801 test_loss: 0.207 test_R^2: 0.794
# Epoch 48 loss: 0.197 R^2: 0.801 test_loss: 0.208 test_R^2: 0.793
# Epoch 49 loss: 0.197 R^2: 0.802 test_loss: 0.208 test_R^2: 0.794
# Epoch 50 loss: 0.197 R^2: 0.802 test_loss: 0.206 test_R^2: 0.795
# Epoch 51 loss: 0.197 R^2: 0.802 test_loss: 0.206 test_R^2: 0.795
# Epoch 52 loss: 0.195 R^2: 0.803 test_loss: 0.205 test_R^2: 0.796
# Epoch 53 loss: 0.195 R^2: 0.803 test_loss: 0.204 test_R^2: 0.797
# Epoch 54 loss: 0.194 R^2: 0.804 test_loss: 0.204 test_R^2: 0.797
# Epoch 55 loss: 0.194 R^2: 0.805 test_loss: 0.205 test_R^2: 0.796
# Epoch 56 loss: 0.194 R^2: 0.805 test_loss: 0.203 test_R^2: 0.798
# Epoch 57 loss: 0.193 R^2: 0.806 test_loss: 0.203 test_R^2: 0.798
# Epoch 58 loss: 0.193 R^2: 0.806 test_loss: 0.202 test_R^2: 0.799
# Epoch 59 loss: 0.193 R^2: 0.805 test_loss: 0.202 test_R^2: 0.799
# Epoch 60 loss: 0.192 R^2: 0.806 test_loss: 0.203 test_R^2: 0.798
# Epoch 61 loss: 0.191 R^2: 0.808 test_loss: 0.202 test_R^2: 0.799
# Epoch 62 loss: 0.192 R^2: 0.807 test_loss: 0.201 test_R^2: 0.800
# Epoch 63 loss: 0.192 R^2: 0.807 test_loss: 0.201 test_R^2: 0.800
# Epoch 64 loss: 0.192 R^2: 0.807 test_loss: 0.201 test_R^2: 0.800
# Epoch 65 loss: 0.191 R^2: 0.808 test_loss: 0.201 test_R^2: 0.800
# Epoch 66 loss: 0.191 R^2: 0.808 test_loss: 0.200 test_R^2: 0.801
# Epoch 67 loss: 0.191 R^2: 0.808 test_loss: 0.201 test_R^2: 0.800
# Epoch 68 loss: 0.190 R^2: 0.808 test_loss: 0.200 test_R^2: 0.801
# Epoch 69 loss: 0.190 R^2: 0.809 test_loss: 0.200 test_R^2: 0.801
# Epoch 70 loss: 0.190 R^2: 0.809 test_loss: 0.200 test_R^2: 0.801
# Epoch 71 loss: 0.190 R^2: 0.809 test_loss: 0.199 test_R^2: 0.802
# Epoch 72 loss: 0.190 R^2: 0.809 test_loss: 0.199 test_R^2: 0.802
# Epoch 73 loss: 0.189 R^2: 0.810 test_loss: 0.199 test_R^2: 0.802
# Epoch 74 loss: 0.189 R^2: 0.809 test_loss: 0.199 test_R^2: 0.802
# Epoch 75 loss: 0.189 R^2: 0.810 test_loss: 0.199 test_R^2: 0.802
# Epoch 76 loss: 0.188 R^2: 0.810 test_loss: 0.198 test_R^2: 0.803
# Epoch 77 loss: 0.189 R^2: 0.810 test_loss: 0.199 test_R^2: 0.802
# Epoch 78 loss: 0.188 R^2: 0.811 test_loss: 0.199 test_R^2: 0.803
# Epoch 79 loss: 0.188 R^2: 0.810 test_loss: 0.198 test_R^2: 0.803
# Epoch 80 loss: 0.189 R^2: 0.810 test_loss: 0.198 test_R^2: 0.803
# Epoch 81 loss: 0.188 R^2: 0.810 test_loss: 0.198 test_R^2: 0.803
# Epoch 82 loss: 0.189 R^2: 0.810 test_loss: 0.198 test_R^2: 0.803
# Epoch 83 loss: 0.188 R^2: 0.811 test_loss: 0.198 test_R^2: 0.803
# Epoch 84 loss: 0.188 R^2: 0.811 test_loss: 0.198 test_R^2: 0.803
# Epoch 85 loss: 0.188 R^2: 0.811 test_loss: 0.198 test_R^2: 0.803
# Epoch 86 loss: 0.187 R^2: 0.812 test_loss: 0.198 test_R^2: 0.804
# Epoch 87 loss: 0.188 R^2: 0.811 test_loss: 0.197 test_R^2: 0.804
# Epoch 88 loss: 0.187 R^2: 0.812 test_loss: 0.198 test_R^2: 0.803
# Epoch 89 loss: 0.188 R^2: 0.811 test_loss: 0.198 test_R^2: 0.804
# Epoch 90 loss: 0.188 R^2: 0.811 test_loss: 0.197 test_R^2: 0.804
# Epoch 91 loss: 0.188 R^2: 0.811 test_loss: 0.197 test_R^2: 0.804
# Epoch 92 loss: 0.188 R^2: 0.811 test_loss: 0.197 test_R^2: 0.804
# Epoch 93 loss: 0.187 R^2: 0.811 test_loss: 0.197 test_R^2: 0.804
# Epoch 94 loss: 0.188 R^2: 0.810 test_loss: 0.197 test_R^2: 0.804
# Epoch 95 loss: 0.187 R^2: 0.812 test_loss: 0.197 test_R^2: 0.804
# Epoch 96 loss: 0.187 R^2: 0.812 test_loss: 0.197 test_R^2: 0.804
# Epoch 97 loss: 0.187 R^2: 0.812 test_loss: 0.197 test_R^2: 0.804
# Epoch 98 loss: 0.187 R^2: 0.812 test_loss: 0.197 test_R^2: 0.804
# Epoch 99 loss: 0.187 R^2: 0.812 test_loss: 0.197 test_R^2: 0.804
# Epoch 100 loss: 0.187 R^2: 0.812 test_loss: 0.197 test_R^2: 0.804

# %%
plt.plot( cur_lrs)
plt.xlabel('Epoch')
plt.ylabel('Learning Rate')
plt.grid()
plt.show()

# %%
path = '/kaggle/working/gru_10k_s_p'
torch.save(net_10k,path)

# %%
with torch.no_grad():
    test_data, test_labels = test_data.to(device), test_labels.to(device)
    test_outputs = net_10k(test_data)    
    pred = test_outputs
pred.shape
# Out:
# torch.Size([2000, 7])

# %%
from scipy.stats import pearsonr

keys = ['T', 'log_P_cloud', 'log_H2O', 'log_CO2', 'log_CO', 'log_CH4', 'log_NH3']
fig, axs = plt.subplots(2, 4, figsize=(20,10))

y_test_rescaled = scaler.inverse_transform(y_test)
predictions = np.array(pred.cpu())
predictions = scaler.inverse_transform(predictions)

for i in range(7):
    if i < 4:
        corr, _ = pearsonr(predictions[:,i], y_test_rescaled[:,i])
        axs[0,i].scatter(y_test_rescaled[:,i],predictions[:,i], marker='x', label=f'$R^{2} = ${corr:.3f}')
        axs[0,i].scatter(y_test_rescaled[:,i],y_test_rescaled[:,i], color='red')
        axs[0,i].set_title(keys[i])
        axs[0,i].legend(loc='upper left',fontsize=12)
        axs[0,i].grid()
    else:
        corr, _ = pearsonr(predictions[:,i], y_test_rescaled[:,i])
        axs[1,i-4].scatter(y_test_rescaled[:,i],predictions[:,i], marker='x',label=f'$R^{2} = ${corr:.3f}')
        axs[1,i-4].scatter(y_test_rescaled[:,i],y_test_rescaled[:,i], color='red')
        axs[1,i-4].set_title(keys[i])
        axs[1,i-4].legend(loc= 'upper left',fontsize=12)
        axs[1,i-4].grid()

# %%
keys = ['T', 'log_P_cloud', 'log_H2O', 'log_CO2', 'log_CO', 'log_CH4', 'log_NH3']
fig, axs = plt.subplots(2, 4, figsize=(20,10))

y_test_rescaled = scaler.inverse_transform(y_test)
predictions = np.array(pred.cpu())
predictions = scaler.inverse_transform(predictions)

for i in range(7):
    if i < 4:
        pred_err = predictions[:,i]-y_test_rescaled[:,i]
        med = np.median(pred_err)
        low = np.percentile(pred_err,15.9)
        high = np.percentile(pred_err,84.1)
        axs[0,i].hist(pred_err,bins=10,color='skyblue')
        axs[0,i].axvline(x=med,color='blue',linestyle='--',label=f'median: {med:.2f}')
        axs[0,i].axvline(x=low,color='black',linestyle=':',label=f'low: {low:.2f}')
        axs[0,i].axvline(x=high,color='black',linestyle=':',label=f'high: {high:.2f}')
        axs[0,i].set_title(keys[i])
        axs[0,i].legend()
        #axs[0,i].set_xlabel('Predicted - True')
    else:
        pred_err = predictions[:,i]-y_test_rescaled[:,i]
        med = np.median(pred_err)
        low = np.percentile(pred_err,15.9)
        high = np.percentile(pred_err,84.1)
        axs[1,i-4].hist(pred_err,bins=10,color='skyblue')
        axs[1,i-4].axvline(x=med,color='blue',linestyle='--',label=f'median: {med:.2f}')
        axs[1,i-4].axvline(x=low,color='black',linestyle=':',label=f'low: {low:.2f}')
        axs[1,i-4].axvline(x=high,color='black',linestyle=':',label=f'high: {high:.2f}')
        axs[1,i-4].set_title(keys[i])
        axs[1,i-4].legend()
        axs[1,i-4].set_xlabel('Predicted - True')

# %%
y_test_rescaled_10k = scaler.inverse_transform(y_test)
predictions_10k = np.array(pred.cpu())
predictions_10k = scaler.inverse_transform(predictions_10k)

# %% [markdown]
# ## Testing on the retreived planets

# %%
file_data = np.load('/kaggle/input/pos-1m-clean/1M_pos_clean_data.npy')

# %%
mean = np.mean(file_data[1,:269])
std = np.std(file_data[1,:269])
planetA_spec = (file_data[1,:269] - mean) / std
FH = np.max(file_data[1,:269]) - np.min(file_data[1,:269])
# planetA_spec = np.concatenate([planetA_spec,np.array([mean]),np.array([std])])
planetA_spec = np.concatenate([planetA_spec,np.array([std]),np.array([file_data[1,269]]), np.array([file_data[1,270]]), np.array([file_data[1,271]])])
planetA_params = file_data[1,269:]
planetA_spec.shape, planetA_params.shape
# Out:
# ((273,), (10,))

# %%
mean = np.mean(file_data[10,:269])
std = np.std(file_data[10,:269])
planetB_spec = (file_data[10,:269] - mean) / std
FH = np.max(file_data[10,:269]) - np.min(file_data[10,:269])
# planetB_spec = np.concatenate([planetB_spec,np.array([mean]),np.array([std])])
planetB_spec = np.concatenate([planetB_spec,np.array([std]),np.array([file_data[10,269]]), np.array([file_data[10,270]]), np.array([file_data[10,271]])])
planetB_params = file_data[10,269:]
planetB_spec.shape, planetB_params.shape
# Out:
# ((273,), (10,))

# %%
mean = np.mean(file_data[100,:269])
std = np.std(file_data[100,:269])
planetC_spec = (file_data[100,:269] - mean) / std
FH = np.max(file_data[100,:269]) - np.min(file_data[100,:269])
# planetC_spec = np.concatenate([planetC_spec,np.array([mean]),np.array([std])])
planetC_spec = np.concatenate([planetC_spec,np.array([std]),np.array([file_data[100,269]]), np.array([file_data[100,270]]), np.array([file_data[100,271]])])
planetC_params = file_data[100,269:]
planetC_spec.shape, planetC_params.shape
# Out:
# ((273,), (10,))

# %%
test_planets = np.array([planetA_spec,planetB_spec,planetC_spec])
test_planets.shape
# Out:
# (3, 273)

# %%
pred_data = torch.from_numpy(test_planets).float()
with torch.no_grad():
    pred_data = pred_data.to(device)
    pred = net_10k(pred_data)    
pred = np.array(pred.cpu())    
pred.shape
# Out:
# (3, 7)

# %%
pred = scaler.inverse_transform(pred)
pred
# Out:
# array([[ 2.1554207e+03, -5.8372849e-01, -6.7624645e+00, -7.6866345e+00,
#         -5.8211670e+00, -3.0597522e+00, -3.9345078e+00],
#        [ 1.0555685e+03,  4.5883831e-02, -2.6384292e+00, -2.8140726e+00,
#         -4.9679389e+00, -6.2180176e+00, -6.2472138e+00],
#        [ 2.6944890e+03, -3.7551055e+00, -6.7351108e+00, -4.9572067e+00,
#         -7.0933728e+00, -2.7072546e+00, -5.5866308e+00]], dtype=float32)

# %%
planetA_pred_10k = pred[0]
print("Predicted values:",planetA_pred_10k)
print("Actual values:",planetA_params[3:])
# Out:
# Predicted values: [ 2.1554207e+03 -5.8372849e-01 -6.7624645e+00 -7.6866345e+00
#  -5.8211670e+00 -3.0597522e+00 -3.9345078e+00]
# Actual values: [ 2.08383676e+03 -1.94865038e-01 -7.35204337e+00 -8.11423364e+00
#  -5.01872241e+00 -3.65232765e+00 -4.16874130e+00]

# %%
planetB_pred_10k = pred[1]
print("Predicted values:",planetB_pred_10k)
print("Actual values:",planetB_params[3:])
# Out:
# Predicted values: [ 1.0555685e+03  4.5883831e-02 -2.6384292e+00 -2.8140726e+00
#  -4.9679389e+00 -6.2180176e+00 -6.2472138e+00]
# Actual values: [ 1.11335948e+03  1.70457392e-01 -2.78129766e+00 -2.70422089e+00
#  -8.81511155e+00 -5.79890730e+00 -5.21304883e+00]

# %%
planetC_pred_10k = pred[2]
print("Predicted values:",planetC_pred_10k)
print("Actual values:",planetC_params[3:])
# Out:
# Predicted values: [2694.489       -3.7551055   -6.7351108   -4.9572067   -7.093373
#    -2.7072546   -5.586631 ]
# Actual values: [ 2.66055847e+03 -3.48554752e+00 -5.39606516e+00 -5.07833705e+00
#  -5.97777151e+00 -2.57789940e+00 -5.33643891e+00]

# %% [markdown]
# ## 100k data

# %%
X = new_spec[:100000]
Y = new_data[:100000,272:]
X.shape, Y.shape

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
Y = scaler.fit_transform(Y)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.20, random_state = 42)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((80000, 273), (20000, 273), (80000, 7), (20000, 7))

# %%
initial_learning_rate = 1e-4
final_learning_rate = 1e-6
epochs = 100
train_size = X_train.shape[0]
batch_size = 32
lr_decay_factor = (final_learning_rate / initial_learning_rate)**(1/epochs)
steps_per_epoch = int(train_size/batch_size)
lr_decay_factor, steps_per_epoch
# Out:
# (0.954992586021436, 2500)

# %%
net_100k = GRUModel()

input_size = (1,X_train.shape[1])
summary(net_100k, input_size)
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# GRUModel                                 [1, 7]                    --
# ├─GRU: 1-1                               [1, 64]                   65,088
# ├─GRU: 1-2                               [1, 128]                  74,496
# ├─GRU: 1-3                               [1, 256]                  296,448
# ├─GRU: 1-4                               [1, 128]                  148,224
# ├─Linear: 1-5                            [1, 7]                    903
# ==========================================================================================
# Total params: 585,159
# Trainable params: 585,159
# Non-trainable params: 0
# Total mult-adds (M): 108.57
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 2.34
# Estimated Total Size (MB): 2.35
# ==========================================================================================

# %%
data = X_train
labels = y_train


data = torch.from_numpy(data).float()
labels = torch.from_numpy(labels).float()


trainset = torch.utils.data.TensorDataset(data, labels)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=32, shuffle=True)


criterion = nn.MSELoss()
optimizer = optim.Adam(net_10k.parameters(), lr=0.0001)
scheduler = ExponentialLR(optimizer,gamma=lr_decay_factor)


device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Train the neural network

epochs = 100

net_100k.to(device)
losses = []
r2s = []
test_losses = []
test_r2s = []
cur_lrs =[]
for epoch in range(epochs):
    net_100k.train()
    running_loss = 0.0
    running_r2 = 0.0
    for i, data in enumerate(trainloader, 0):
        
        
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = net_100k(inputs)
        loss = criterion(outputs, labels)
        r2 = R2Loss()(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        running_r2 += r2.item()
    losses.append(running_loss / len(trainloader))
    r2s.append(running_r2 / len(trainloader))
#         print('Epoch %d loss: %.3f R^2: %.3f' % (epoch + 1, running_loss / len(trainloader), running_r2 / len(trainloader)))
    
    # Test the neural network on the test data
    test_data = X_test
    test_labels = y_test
    test_data = torch.from_numpy(test_data).float()
    test_labels = torch.from_numpy(test_labels).float()
    net_100k.eval()
    with torch.no_grad():
        test_data, test_labels = test_data.to(device), test_labels.to(device)
        test_outputs = net_100k(test_data)
        test_loss = criterion(test_outputs, test_labels)
        test_r2 = R2Loss()(test_outputs, test_labels)
        test_losses.append(test_loss.item())
        test_r2s.append(test_r2.item())
    current_lr = optimizer.param_groups[0]['lr']
    cur_lrs.append(current_lr)
    print('Epoch %d loss: %.3f R^2: %.3f test_loss: %.3f test_R^2: %.3f  ' % (epoch + 1, running_loss / len(trainloader), running_r2 / len(trainloader), test_loss, test_r2))    
    scheduler.step()
    
# plotting model loss    
plt.plot(losses,label='train_loss')
plt.plot(test_losses, label='test_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Model loss')
plt.legend()
plt.grid()
plt.show()
# plotting model r2 score
plt.plot(r2s, label='train_r2')
plt.plot(test_r2s, label='test_r2')
plt.xlabel('Epoch')
plt.ylabel('R^2')
plt.title('Model $R^{2}$ score')
plt.legend()
plt.grid()
plt.show()
# Out:
# Epoch 1 loss: 0.455 R^2: 0.543 test_loss: 0.281 test_R^2: 0.719
# Epoch 2 loss: 0.241 R^2: 0.758 test_loss: 0.212 test_R^2: 0.788
# Epoch 3 loss: 0.196 R^2: 0.804 test_loss: 0.194 test_R^2: 0.806
# Epoch 4 loss: 0.170 R^2: 0.830 test_loss: 0.164 test_R^2: 0.836
# Epoch 5 loss: 0.152 R^2: 0.848 test_loss: 0.145 test_R^2: 0.854
# Epoch 6 loss: 0.140 R^2: 0.859 test_loss: 0.136 test_R^2: 0.863
# Epoch 7 loss: 0.131 R^2: 0.868 test_loss: 0.128 test_R^2: 0.872
# Epoch 8 loss: 0.125 R^2: 0.875 test_loss: 0.124 test_R^2: 0.876
# Epoch 9 loss: 0.119 R^2: 0.881 test_loss: 0.119 test_R^2: 0.881
# Epoch 10 loss: 0.114 R^2: 0.886 test_loss: 0.111 test_R^2: 0.889
# Epoch 11 loss: 0.110 R^2: 0.890 test_loss: 0.108 test_R^2: 0.892
# Epoch 12 loss: 0.106 R^2: 0.893 test_loss: 0.105 test_R^2: 0.895
# Epoch 13 loss: 0.104 R^2: 0.896 test_loss: 0.102 test_R^2: 0.898
# Epoch 14 loss: 0.100 R^2: 0.899 test_loss: 0.098 test_R^2: 0.902
# Epoch 15 loss: 0.098 R^2: 0.902 test_loss: 0.099 test_R^2: 0.901
# Epoch 16 loss: 0.096 R^2: 0.904 test_loss: 0.102 test_R^2: 0.898
# Epoch 17 loss: 0.094 R^2: 0.906 test_loss: 0.094 test_R^2: 0.906
# Epoch 18 loss: 0.092 R^2: 0.908 test_loss: 0.091 test_R^2: 0.909
# Epoch 19 loss: 0.090 R^2: 0.910 test_loss: 0.087 test_R^2: 0.913
# Epoch 20 loss: 0.088 R^2: 0.911 test_loss: 0.089 test_R^2: 0.910
# Epoch 21 loss: 0.087 R^2: 0.913 test_loss: 0.091 test_R^2: 0.909
# Epoch 22 loss: 0.085 R^2: 0.914 test_loss: 0.087 test_R^2: 0.913
# Epoch 23 loss: 0.084 R^2: 0.916 test_loss: 0.086 test_R^2: 0.914
# Epoch 24 loss: 0.083 R^2: 0.917 test_loss: 0.083 test_R^2: 0.917
# Epoch 25 loss: 0.082 R^2: 0.918 test_loss: 0.082 test_R^2: 0.918
# Epoch 26 loss: 0.081 R^2: 0.919 test_loss: 0.086 test_R^2: 0.914
# Epoch 27 loss: 0.080 R^2: 0.920 test_loss: 0.082 test_R^2: 0.918
# Epoch 28 loss: 0.079 R^2: 0.921 test_loss: 0.080 test_R^2: 0.920
# Epoch 29 loss: 0.078 R^2: 0.922 test_loss: 0.081 test_R^2: 0.919
# Epoch 30 loss: 0.077 R^2: 0.923 test_loss: 0.084 test_R^2: 0.915
# Epoch 31 loss: 0.076 R^2: 0.924 test_loss: 0.081 test_R^2: 0.919
# Epoch 32 loss: 0.075 R^2: 0.924 test_loss: 0.078 test_R^2: 0.922
# Epoch 33 loss: 0.075 R^2: 0.925 test_loss: 0.078 test_R^2: 0.922
# Epoch 34 loss: 0.074 R^2: 0.926 test_loss: 0.074 test_R^2: 0.926
# Epoch 35 loss: 0.073 R^2: 0.926 test_loss: 0.076 test_R^2: 0.924
# Epoch 36 loss: 0.073 R^2: 0.927 test_loss: 0.073 test_R^2: 0.927
# Epoch 37 loss: 0.072 R^2: 0.928 test_loss: 0.073 test_R^2: 0.927
# Epoch 38 loss: 0.072 R^2: 0.928 test_loss: 0.072 test_R^2: 0.928
# Epoch 39 loss: 0.071 R^2: 0.929 test_loss: 0.072 test_R^2: 0.928
# Epoch 40 loss: 0.071 R^2: 0.929 test_loss: 0.073 test_R^2: 0.926
# Epoch 41 loss: 0.070 R^2: 0.930 test_loss: 0.073 test_R^2: 0.927
# Epoch 42 loss: 0.070 R^2: 0.930 test_loss: 0.071 test_R^2: 0.929
# Epoch 43 loss: 0.069 R^2: 0.930 test_loss: 0.070 test_R^2: 0.930
# Epoch 44 loss: 0.069 R^2: 0.931 test_loss: 0.073 test_R^2: 0.927
# Epoch 45 loss: 0.069 R^2: 0.931 test_loss: 0.071 test_R^2: 0.929
# Epoch 46 loss: 0.068 R^2: 0.932 test_loss: 0.069 test_R^2: 0.931
# Epoch 47 loss: 0.068 R^2: 0.932 test_loss: 0.069 test_R^2: 0.931
# Epoch 48 loss: 0.068 R^2: 0.932 test_loss: 0.071 test_R^2: 0.929
# Epoch 49 loss: 0.067 R^2: 0.932 test_loss: 0.071 test_R^2: 0.929
# Epoch 50 loss: 0.067 R^2: 0.933 test_loss: 0.070 test_R^2: 0.930
# Epoch 51 loss: 0.067 R^2: 0.933 test_loss: 0.067 test_R^2: 0.933
# Epoch 52 loss: 0.066 R^2: 0.934 test_loss: 0.070 test_R^2: 0.930
# Epoch 53 loss: 0.066 R^2: 0.934 test_loss: 0.067 test_R^2: 0.933
# Epoch 54 loss: 0.066 R^2: 0.934 test_loss: 0.067 test_R^2: 0.933
# Epoch 55 loss: 0.066 R^2: 0.934 test_loss: 0.068 test_R^2: 0.932
# Epoch 56 loss: 0.065 R^2: 0.934 test_loss: 0.067 test_R^2: 0.933
# Epoch 57 loss: 0.065 R^2: 0.935 test_loss: 0.067 test_R^2: 0.933
# Epoch 58 loss: 0.065 R^2: 0.935 test_loss: 0.066 test_R^2: 0.934
# Epoch 59 loss: 0.065 R^2: 0.935 test_loss: 0.067 test_R^2: 0.933
# Epoch 60 loss: 0.065 R^2: 0.935 test_loss: 0.068 test_R^2: 0.932
# Epoch 61 loss: 0.064 R^2: 0.935 test_loss: 0.066 test_R^2: 0.934
# Epoch 62 loss: 0.064 R^2: 0.935 test_loss: 0.066 test_R^2: 0.934
# Epoch 63 loss: 0.064 R^2: 0.936 test_loss: 0.065 test_R^2: 0.935
# Epoch 64 loss: 0.064 R^2: 0.936 test_loss: 0.066 test_R^2: 0.933
# Epoch 65 loss: 0.064 R^2: 0.936 test_loss: 0.065 test_R^2: 0.934
# Epoch 66 loss: 0.064 R^2: 0.936 test_loss: 0.066 test_R^2: 0.934
# Epoch 67 loss: 0.064 R^2: 0.936 test_loss: 0.066 test_R^2: 0.934
# Epoch 68 loss: 0.063 R^2: 0.936 test_loss: 0.065 test_R^2: 0.935
# Epoch 69 loss: 0.063 R^2: 0.936 test_loss: 0.066 test_R^2: 0.934
# Epoch 70 loss: 0.063 R^2: 0.937 test_loss: 0.065 test_R^2: 0.935
# Epoch 71 loss: 0.063 R^2: 0.937 test_loss: 0.066 test_R^2: 0.934
# Epoch 72 loss: 0.063 R^2: 0.937 test_loss: 0.066 test_R^2: 0.933
# Epoch 73 loss: 0.063 R^2: 0.937 test_loss: 0.068 test_R^2: 0.932
# Epoch 74 loss: 0.063 R^2: 0.937 test_loss: 0.064 test_R^2: 0.936
# Epoch 75 loss: 0.063 R^2: 0.937 test_loss: 0.065 test_R^2: 0.935
# Epoch 76 loss: 0.063 R^2: 0.937 test_loss: 0.065 test_R^2: 0.935
# Epoch 77 loss: 0.062 R^2: 0.937 test_loss: 0.064 test_R^2: 0.936
# Epoch 78 loss: 0.062 R^2: 0.937 test_loss: 0.065 test_R^2: 0.935
# Epoch 79 loss: 0.062 R^2: 0.937 test_loss: 0.065 test_R^2: 0.935
# Epoch 80 loss: 0.062 R^2: 0.938 test_loss: 0.064 test_R^2: 0.936
# Epoch 81 loss: 0.062 R^2: 0.938 test_loss: 0.064 test_R^2: 0.936
# Epoch 82 loss: 0.062 R^2: 0.938 test_loss: 0.064 test_R^2: 0.936
# Epoch 83 loss: 0.062 R^2: 0.938 test_loss: 0.065 test_R^2: 0.935
# Epoch 84 loss: 0.062 R^2: 0.938 test_loss: 0.064 test_R^2: 0.936
# Epoch 85 loss: 0.062 R^2: 0.938 test_loss: 0.064 test_R^2: 0.936
# Epoch 86 loss: 0.062 R^2: 0.938 test_loss: 0.064 test_R^2: 0.936
# Epoch 87 loss: 0.062 R^2: 0.938 test_loss: 0.064 test_R^2: 0.936
# Epoch 88 loss: 0.062 R^2: 0.938 test_loss: 0.063 test_R^2: 0.937
# Epoch 89 loss: 0.062 R^2: 0.938 test_loss: 0.064 test_R^2: 0.936
# Epoch 90 loss: 0.062 R^2: 0.938 test_loss: 0.064 test_R^2: 0.936
# Epoch 91 loss: 0.062 R^2: 0.938 test_loss: 0.064 test_R^2: 0.936
# Epoch 92 loss: 0.062 R^2: 0.938 test_loss: 0.064 test_R^2: 0.936
# Epoch 93 loss: 0.061 R^2: 0.938 test_loss: 0.063 test_R^2: 0.937
# Epoch 94 loss: 0.061 R^2: 0.938 test_loss: 0.064 test_R^2: 0.936
# Epoch 95 loss: 0.061 R^2: 0.938 test_loss: 0.063 test_R^2: 0.937
# Epoch 96 loss: 0.062 R^2: 0.938 test_loss: 0.063 test_R^2: 0.937
# Epoch 97 loss: 0.061 R^2: 0.938 test_loss: 0.063 test_R^2: 0.937
# Epoch 98 loss: 0.061 R^2: 0.938 test_loss: 0.064 test_R^2: 0.936
# Epoch 99 loss: 0.061 R^2: 0.938 test_loss: 0.063 test_R^2: 0.936
# Epoch 100 loss: 0.061 R^2: 0.939 test_loss: 0.063 test_R^2: 0.937

# %%
plt.plot( cur_lrs)
plt.xlabel('Epoch')
plt.ylabel('Learning Rate')
plt.grid()
plt.show()

# %%
path = '/kaggle/working/gru_100k_s_p'
torch.save(net_100k,path)

# %%
with torch.no_grad():
    test_data, test_labels = test_data.to(device), test_labels.to(device)
    test_outputs = net_100k(test_data)    
    pred = test_outputs
pred.shape
# Out:
# torch.Size([20000, 7])

# %%
from scipy.stats import pearsonr

keys = ['T', 'log_P_cloud', 'log_H2O', 'log_CO2', 'log_CO', 'log_CH4', 'log_NH3']
fig, axs = plt.subplots(2, 4, figsize=(20,10))

y_test_rescaled = scaler.inverse_transform(y_test)
predictions = np.array(pred.cpu())
predictions = scaler.inverse_transform(predictions)

for i in range(7):
    if i < 4:
        corr, _ = pearsonr(predictions[:,i], y_test_rescaled[:,i])
        axs[0,i].scatter(y_test_rescaled[:,i],predictions[:,i], marker='x', label=f'$R^{2} = ${corr:.3f}')
        axs[0,i].scatter(y_test_rescaled[:,i],y_test_rescaled[:,i], color='red')
        axs[0,i].set_title(keys[i])
        axs[0,i].legend(loc='upper left',fontsize=12)
        axs[0,i].grid()
    else:
        corr, _ = pearsonr(predictions[:,i], y_test_rescaled[:,i])
        axs[1,i-4].scatter(y_test_rescaled[:,i],predictions[:,i], marker='x',label=f'$R^{2} = ${corr:.3f}')
        axs[1,i-4].scatter(y_test_rescaled[:,i],y_test_rescaled[:,i], color='red')
        axs[1,i-4].set_title(keys[i])
        axs[1,i-4].legend(loc= 'upper left',fontsize=12)
        axs[1,i-4].grid()

# %%
keys = ['T', 'log_P_cloud', 'log_H2O', 'log_CO2', 'log_CO', 'log_CH4', 'log_NH3']
fig, axs = plt.subplots(2, 4, figsize=(20,10))

y_test_rescaled = scaler.inverse_transform(y_test)
predictions = np.array(pred.cpu())
predictions = scaler.inverse_transform(predictions)

for i in range(7):
    if i < 4:
        pred_err = predictions[:,i]-y_test_rescaled[:,i]
        med = np.median(pred_err)
        low = np.percentile(pred_err,15.9)
        high = np.percentile(pred_err,84.1)
        axs[0,i].hist(pred_err,bins=10,color='skyblue')
        axs[0,i].axvline(x=med,color='blue',linestyle='--',label=f'median: {med:.2f}')
        axs[0,i].axvline(x=low,color='black',linestyle=':',label=f'low: {low:.2f}')
        axs[0,i].axvline(x=high,color='black',linestyle=':',label=f'high: {high:.2f}')
        axs[0,i].set_title(keys[i])
        axs[0,i].legend()
        #axs[0,i].set_xlabel('Predicted - True')
    else:
        pred_err = predictions[:,i]-y_test_rescaled[:,i]
        med = np.median(pred_err)
        low = np.percentile(pred_err,15.9)
        high = np.percentile(pred_err,84.1)
        axs[1,i-4].hist(pred_err,bins=10,color='skyblue')
        axs[1,i-4].axvline(x=med,color='blue',linestyle='--',label=f'median: {med:.2f}')
        axs[1,i-4].axvline(x=low,color='black',linestyle=':',label=f'low: {low:.2f}')
        axs[1,i-4].axvline(x=high,color='black',linestyle=':',label=f'high: {high:.2f}')
        axs[1,i-4].set_title(keys[i])
        axs[1,i-4].legend()
        axs[1,i-4].set_xlabel('Predicted - True')

# %%
y_test_rescaled_100k = scaler.inverse_transform(y_test)
predictions_100k = np.array(pred.cpu())
predictions_100k = scaler.inverse_transform(predictions_100k)

# %%
pred_data = torch.from_numpy(test_planets).float()
with torch.no_grad():
    pred_data = pred_data.to(device)
    pred = net_100k(pred_data)    
pred = np.array(pred.cpu())    
pred = scaler.inverse_transform(pred)
pred
# Out:
# array([[ 2.0833975e+03, -7.0318207e-02, -7.5275259e+00, -8.6580210e+00,
#         -5.1186228e+00, -3.9969199e+00, -4.1194835e+00],
#        [ 1.0657147e+03,  2.8823593e-01, -2.7741754e+00, -2.3206680e+00,
#         -7.8605328e+00, -5.5356817e+00, -4.8176823e+00],
#        [ 2.6108464e+03, -3.5348196e+00, -6.2151413e+00, -5.2551799e+00,
#         -6.7477160e+00, -2.7824814e+00, -6.9278173e+00]], dtype=float32)

# %%
planetA_pred_100k = pred[0]
print("Predicted values:",planetA_pred_100k)
print("Actual values:",planetA_params[3:])
# Out:
# Predicted values: [ 2.0833975e+03 -7.0318207e-02 -7.5275259e+00 -8.6580210e+00
#  -5.1186228e+00 -3.9969199e+00 -4.1194835e+00]
# Actual values: [ 2.08383676e+03 -1.94865038e-01 -7.35204337e+00 -8.11423364e+00
#  -5.01872241e+00 -3.65232765e+00 -4.16874130e+00]

# %%
planetB_pred_100k = pred[1]
print("Predicted values:",planetB_pred_100k)
print("Actual values:",planetB_params[3:])
# Out:
# Predicted values: [ 1.0657147e+03  2.8823593e-01 -2.7741754e+00 -2.3206680e+00
#  -7.8605328e+00 -5.5356817e+00 -4.8176823e+00]
# Actual values: [ 1.11335948e+03  1.70457392e-01 -2.78129766e+00 -2.70422089e+00
#  -8.81511155e+00 -5.79890730e+00 -5.21304883e+00]

# %%
planetC_pred_100k = pred[2]
print("Predicted values:",planetC_pred_100k)
print("Actual values:",planetC_params[3:])
# Out:
# Predicted values: [2610.8464      -3.5348196   -6.2151413   -5.25518     -6.747716
#    -2.7824814   -6.9278173]
# Actual values: [ 2.66055847e+03 -3.48554752e+00 -5.39606516e+00 -5.07833705e+00
#  -5.97777151e+00 -2.57789940e+00 -5.33643891e+00]

# %% [markdown]
# ## 1M data

# %%
X = new_spec
Y = new_data[:,272:]
X.shape, Y.shape

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
Y = scaler.fit_transform(Y)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.20, random_state = 42)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((796780, 273), (199195, 273), (796780, 7), (199195, 7))

# %%
initial_learning_rate = 1e-4
final_learning_rate = 1e-6
epochs = 100
train_size = X_train.shape[0]
batch_size = 32
lr_decay_factor = (final_learning_rate / initial_learning_rate)**(1/epochs)
steps_per_epoch = int(train_size/batch_size)
lr_decay_factor, steps_per_epoch
# Out:
# (0.954992586021436, 24899)

# %%
net_1m = GRUModel()

input_size = (1,X_train.shape[1])
summary(net_1m, input_size)
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# GRUModel                                 [1, 7]                    --
# ├─GRU: 1-1                               [1, 64]                   65,088
# ├─GRU: 1-2                               [1, 128]                  74,496
# ├─GRU: 1-3                               [1, 256]                  296,448
# ├─GRU: 1-4                               [1, 128]                  148,224
# ├─Linear: 1-5                            [1, 7]                    903
# ==========================================================================================
# Total params: 585,159
# Trainable params: 585,159
# Non-trainable params: 0
# Total mult-adds (M): 108.57
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 2.34
# Estimated Total Size (MB): 2.35
# ==========================================================================================

# %%
data = X_train
labels = y_train


data = torch.from_numpy(data).float()
labels = torch.from_numpy(labels).float()


trainset = torch.utils.data.TensorDataset(data, labels)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=32, shuffle=True)


criterion = nn.MSELoss()
optimizer = optim.Adam(net_10k.parameters(), lr=0.0001)
scheduler = ExponentialLR(optimizer,gamma=lr_decay_factor)


device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Train the neural network

epochs = 100

net_1m.to(device)
losses = []
r2s = []
test_losses = []
test_r2s = []
cur_lrs =[]
for epoch in range(epochs):
    net_1m.train()
    running_loss = 0.0
    running_r2 = 0.0
    for i, data in enumerate(trainloader, 0):
        
        
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = net_1m(inputs)
        loss = criterion(outputs, labels)
        r2 = R2Loss()(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        running_r2 += r2.item()
    losses.append(running_loss / len(trainloader))
    r2s.append(running_r2 / len(trainloader))
#         print('Epoch %d loss: %.3f R^2: %.3f' % (epoch + 1, running_loss / len(trainloader), running_r2 / len(trainloader)))
    
    # Test the neural network on the test data
    test_data = X_test
    test_labels = y_test
    test_data = torch.from_numpy(test_data).float()
    test_labels = torch.from_numpy(test_labels).float()
    net_1m.eval()
    with torch.no_grad():
        test_data, test_labels = test_data.to(device), test_labels.to(device)
        test_outputs = net_1m(test_data)
        test_loss = criterion(test_outputs, test_labels)
        test_r2 = R2Loss()(test_outputs, test_labels)
        test_losses.append(test_loss.item())
        test_r2s.append(test_r2.item())
    current_lr = optimizer.param_groups[0]['lr']
    cur_lrs.append(current_lr)
    print('Epoch %d loss: %.3f R^2: %.3f test_loss: %.3f test_R^2: %.3f  ' % (epoch + 1, running_loss / len(trainloader), running_r2 / len(trainloader), test_loss, test_r2))    
    scheduler.step()
    
# plotting model loss    
plt.plot(losses,label='train_loss')
plt.plot(test_losses, label='test_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Model loss')
plt.legend()
plt.grid()
plt.show()
# plotting model r2 score
plt.plot(r2s, label='train_r2')
plt.plot(test_r2s, label='test_r2')
plt.xlabel('Epoch')
plt.ylabel('R^2')
plt.title('Model $R^{2}$ score')
plt.legend()
plt.grid()
plt.show()
# Out:
# Epoch 1 loss: 0.182 R^2: 0.817 test_loss: 0.120 test_R^2: 0.880
# Epoch 2 loss: 0.095 R^2: 0.905 test_loss: 0.084 test_R^2: 0.916
# Epoch 3 loss: 0.078 R^2: 0.922 test_loss: 0.078 test_R^2: 0.922
# Epoch 4 loss: 0.069 R^2: 0.931 test_loss: 0.063 test_R^2: 0.937
# Epoch 5 loss: 0.063 R^2: 0.936 test_loss: 0.063 test_R^2: 0.937
# Epoch 6 loss: 0.059 R^2: 0.941 test_loss: 0.058 test_R^2: 0.942
# Epoch 7 loss: 0.056 R^2: 0.944 test_loss: 0.050 test_R^2: 0.950
# Epoch 8 loss: 0.053 R^2: 0.946 test_loss: 0.058 test_R^2: 0.942
# Epoch 9 loss: 0.051 R^2: 0.949 test_loss: 0.046 test_R^2: 0.954
# Epoch 10 loss: 0.049 R^2: 0.950 test_loss: 0.050 test_R^2: 0.950
# Epoch 11 loss: 0.048 R^2: 0.952 test_loss: 0.046 test_R^2: 0.954
# Epoch 12 loss: 0.046 R^2: 0.954 test_loss: 0.041 test_R^2: 0.959
# Epoch 13 loss: 0.045 R^2: 0.955 test_loss: 0.045 test_R^2: 0.955
# Epoch 14 loss: 0.044 R^2: 0.956 test_loss: 0.039 test_R^2: 0.961
# Epoch 15 loss: 0.043 R^2: 0.957 test_loss: 0.043 test_R^2: 0.957
# Epoch 16 loss: 0.042 R^2: 0.958 test_loss: 0.039 test_R^2: 0.961
# Epoch 17 loss: 0.041 R^2: 0.959 test_loss: 0.038 test_R^2: 0.962
# Epoch 18 loss: 0.040 R^2: 0.960 test_loss: 0.038 test_R^2: 0.962
# Epoch 19 loss: 0.039 R^2: 0.961 test_loss: 0.038 test_R^2: 0.962
# Epoch 20 loss: 0.038 R^2: 0.962 test_loss: 0.036 test_R^2: 0.964
# Epoch 21 loss: 0.037 R^2: 0.962 test_loss: 0.035 test_R^2: 0.965
# Epoch 22 loss: 0.037 R^2: 0.963 test_loss: 0.036 test_R^2: 0.964
# Epoch 23 loss: 0.036 R^2: 0.964 test_loss: 0.034 test_R^2: 0.966
# Epoch 24 loss: 0.035 R^2: 0.964 test_loss: 0.036 test_R^2: 0.964
# Epoch 25 loss: 0.035 R^2: 0.965 test_loss: 0.039 test_R^2: 0.961
# Epoch 26 loss: 0.034 R^2: 0.966 test_loss: 0.035 test_R^2: 0.965
# Epoch 27 loss: 0.034 R^2: 0.966 test_loss: 0.033 test_R^2: 0.967
# Epoch 28 loss: 0.033 R^2: 0.967 test_loss: 0.032 test_R^2: 0.968
# Epoch 29 loss: 0.033 R^2: 0.967 test_loss: 0.031 test_R^2: 0.969
# Epoch 30 loss: 0.032 R^2: 0.968 test_loss: 0.033 test_R^2: 0.967
# Epoch 31 loss: 0.032 R^2: 0.968 test_loss: 0.029 test_R^2: 0.971
# Epoch 32 loss: 0.031 R^2: 0.968 test_loss: 0.030 test_R^2: 0.970
# Epoch 33 loss: 0.031 R^2: 0.969 test_loss: 0.028 test_R^2: 0.972
# Epoch 34 loss: 0.031 R^2: 0.969 test_loss: 0.030 test_R^2: 0.970
# Epoch 35 loss: 0.030 R^2: 0.970 test_loss: 0.029 test_R^2: 0.971
# Epoch 36 loss: 0.030 R^2: 0.970 test_loss: 0.029 test_R^2: 0.971
# Epoch 37 loss: 0.030 R^2: 0.970 test_loss: 0.028 test_R^2: 0.972
# Epoch 38 loss: 0.029 R^2: 0.971 test_loss: 0.028 test_R^2: 0.972
# Epoch 39 loss: 0.029 R^2: 0.971 test_loss: 0.027 test_R^2: 0.973
# Epoch 40 loss: 0.029 R^2: 0.971 test_loss: 0.027 test_R^2: 0.973
# Epoch 41 loss: 0.028 R^2: 0.972 test_loss: 0.029 test_R^2: 0.971
# Epoch 42 loss: 0.028 R^2: 0.972 test_loss: 0.027 test_R^2: 0.973
# Epoch 43 loss: 0.028 R^2: 0.972 test_loss: 0.027 test_R^2: 0.973
# Epoch 44 loss: 0.028 R^2: 0.972 test_loss: 0.028 test_R^2: 0.972
# Epoch 45 loss: 0.027 R^2: 0.973 test_loss: 0.027 test_R^2: 0.973
# Epoch 46 loss: 0.027 R^2: 0.973 test_loss: 0.027 test_R^2: 0.973
# Epoch 47 loss: 0.027 R^2: 0.973 test_loss: 0.027 test_R^2: 0.973
# Epoch 48 loss: 0.027 R^2: 0.973 test_loss: 0.026 test_R^2: 0.974
# Epoch 49 loss: 0.026 R^2: 0.974 test_loss: 0.025 test_R^2: 0.975
# Epoch 50 loss: 0.026 R^2: 0.974 test_loss: 0.025 test_R^2: 0.975
# Epoch 51 loss: 0.026 R^2: 0.974 test_loss: 0.026 test_R^2: 0.974
# Epoch 52 loss: 0.026 R^2: 0.974 test_loss: 0.025 test_R^2: 0.975
# Epoch 53 loss: 0.026 R^2: 0.974 test_loss: 0.025 test_R^2: 0.975
# Epoch 54 loss: 0.025 R^2: 0.975 test_loss: 0.025 test_R^2: 0.975
# Epoch 55 loss: 0.025 R^2: 0.975 test_loss: 0.025 test_R^2: 0.975
# Epoch 56 loss: 0.025 R^2: 0.975 test_loss: 0.025 test_R^2: 0.975
# Epoch 57 loss: 0.025 R^2: 0.975 test_loss: 0.025 test_R^2: 0.975
# Epoch 58 loss: 0.025 R^2: 0.975 test_loss: 0.025 test_R^2: 0.975
# Epoch 59 loss: 0.025 R^2: 0.975 test_loss: 0.024 test_R^2: 0.976
# Epoch 60 loss: 0.024 R^2: 0.975 test_loss: 0.023 test_R^2: 0.977
# Epoch 61 loss: 0.024 R^2: 0.976 test_loss: 0.024 test_R^2: 0.976
# Epoch 62 loss: 0.024 R^2: 0.976 test_loss: 0.024 test_R^2: 0.976
# Epoch 63 loss: 0.024 R^2: 0.976 test_loss: 0.023 test_R^2: 0.977
# Epoch 64 loss: 0.024 R^2: 0.976 test_loss: 0.023 test_R^2: 0.977
# Epoch 65 loss: 0.024 R^2: 0.976 test_loss: 0.024 test_R^2: 0.977
# Epoch 66 loss: 0.024 R^2: 0.976 test_loss: 0.023 test_R^2: 0.977
# Epoch 67 loss: 0.024 R^2: 0.976 test_loss: 0.023 test_R^2: 0.977
# Epoch 68 loss: 0.023 R^2: 0.976 test_loss: 0.023 test_R^2: 0.977
# Epoch 69 loss: 0.023 R^2: 0.977 test_loss: 0.023 test_R^2: 0.977
# Epoch 70 loss: 0.023 R^2: 0.977 test_loss: 0.024 test_R^2: 0.976
# Epoch 71 loss: 0.023 R^2: 0.977 test_loss: 0.023 test_R^2: 0.977
# Epoch 72 loss: 0.023 R^2: 0.977 test_loss: 0.023 test_R^2: 0.977
# Epoch 73 loss: 0.023 R^2: 0.977 test_loss: 0.023 test_R^2: 0.977
# Epoch 74 loss: 0.023 R^2: 0.977 test_loss: 0.023 test_R^2: 0.977
# Epoch 75 loss: 0.023 R^2: 0.977 test_loss: 0.024 test_R^2: 0.976
# Epoch 76 loss: 0.023 R^2: 0.977 test_loss: 0.023 test_R^2: 0.977
# Epoch 77 loss: 0.023 R^2: 0.977 test_loss: 0.023 test_R^2: 0.977
# Epoch 78 loss: 0.023 R^2: 0.977 test_loss: 0.023 test_R^2: 0.977
# Epoch 79 loss: 0.023 R^2: 0.977 test_loss: 0.023 test_R^2: 0.977
# Epoch 80 loss: 0.023 R^2: 0.977 test_loss: 0.023 test_R^2: 0.977
# Epoch 81 loss: 0.022 R^2: 0.977 test_loss: 0.023 test_R^2: 0.977
# Epoch 82 loss: 0.022 R^2: 0.978 test_loss: 0.023 test_R^2: 0.977
# Epoch 83 loss: 0.022 R^2: 0.978 test_loss: 0.023 test_R^2: 0.977
# Epoch 84 loss: 0.022 R^2: 0.978 test_loss: 0.023 test_R^2: 0.977
# Epoch 85 loss: 0.022 R^2: 0.978 test_loss: 0.023 test_R^2: 0.977
# Epoch 86 loss: 0.022 R^2: 0.978 test_loss: 0.023 test_R^2: 0.977
# Epoch 87 loss: 0.022 R^2: 0.978 test_loss: 0.023 test_R^2: 0.977
# Epoch 88 loss: 0.022 R^2: 0.978 test_loss: 0.023 test_R^2: 0.977
# Epoch 89 loss: 0.022 R^2: 0.978 test_loss: 0.023 test_R^2: 0.977
# Epoch 90 loss: 0.022 R^2: 0.978 test_loss: 0.023 test_R^2: 0.977
# Epoch 91 loss: 0.022 R^2: 0.978 test_loss: 0.023 test_R^2: 0.977
# Epoch 92 loss: 0.022 R^2: 0.978 test_loss: 0.023 test_R^2: 0.977
# Epoch 93 loss: 0.022 R^2: 0.978 test_loss: 0.024 test_R^2: 0.976
# Epoch 94 loss: 0.022 R^2: 0.978 test_loss: 0.024 test_R^2: 0.976
# Epoch 95 loss: 0.022 R^2: 0.978 test_loss: 0.024 test_R^2: 0.976
# Epoch 96 loss: 0.022 R^2: 0.978 test_loss: 0.023 test_R^2: 0.977
# Epoch 97 loss: 0.022 R^2: 0.978 test_loss: 0.023 test_R^2: 0.977
# Epoch 98 loss: 0.022 R^2: 0.978 test_loss: 0.024 test_R^2: 0.977
# Epoch 99 loss: 0.022 R^2: 0.978 test_loss: 0.024 test_R^2: 0.976
# Epoch 100 loss: 0.022 R^2: 0.978 test_loss: 0.024 test_R^2: 0.976

# %%
plt.plot( cur_lrs)
plt.xlabel('Epoch')
plt.ylabel('Learning Rate')
plt.grid()
plt.show()

# %%
path = '/kaggle/working/gru_1M_s_p'
torch.save(net_1m,path)

# %%
with torch.no_grad():
    test_data, test_labels = test_data.to(device), test_labels.to(device)
    test_outputs = net_1m(test_data)    
    pred = test_outputs
pred.shape
# Out:
# torch.Size([199195, 7])

# %%
from scipy.stats import pearsonr

keys = ['T', 'log_P_cloud', 'log_H2O', 'log_CO2', 'log_CO', 'log_CH4', 'log_NH3']
fig, axs = plt.subplots(2, 4, figsize=(20,10))

y_test_rescaled = scaler.inverse_transform(y_test)
predictions = np.array(pred.cpu())
predictions = scaler.inverse_transform(predictions)

for i in range(7):
    if i < 4:
        corr, _ = pearsonr(predictions[:,i], y_test_rescaled[:,i])
        axs[0,i].scatter(y_test_rescaled[:,i],predictions[:,i], marker='x', label=f'$R^{2} = ${corr:.3f}')
        axs[0,i].scatter(y_test_rescaled[:,i],y_test_rescaled[:,i], color='red')
        axs[0,i].set_title(keys[i])
        axs[0,i].legend(loc='upper left',fontsize=12)
        axs[0,i].grid()
    else:
        corr, _ = pearsonr(predictions[:,i], y_test_rescaled[:,i])
        axs[1,i-4].scatter(y_test_rescaled[:,i],predictions[:,i], marker='x',label=f'$R^{2} = ${corr:.3f}')
        axs[1,i-4].scatter(y_test_rescaled[:,i],y_test_rescaled[:,i], color='red')
        axs[1,i-4].set_title(keys[i])
        axs[1,i-4].legend(loc= 'upper left',fontsize=12)
        axs[1,i-4].grid()

# %%
keys = ['T', 'log_P_cloud', 'log_H2O', 'log_CO2', 'log_CO', 'log_CH4', 'log_NH3']
fig, axs = plt.subplots(2, 4, figsize=(20,10))

y_test_rescaled = scaler.inverse_transform(y_test)
predictions = np.array(pred.cpu())
predictions = scaler.inverse_transform(predictions)

for i in range(7):
    if i < 4:
        pred_err = predictions[:,i]-y_test_rescaled[:,i]
        med = np.median(pred_err)
        low = np.percentile(pred_err,15.9)
        high = np.percentile(pred_err,84.1)
        axs[0,i].hist(pred_err,bins=10,color='skyblue')
        axs[0,i].axvline(x=med,color='blue',linestyle='--',label=f'median: {med:.2f}')
        axs[0,i].axvline(x=low,color='black',linestyle=':',label=f'low: {low:.2f}')
        axs[0,i].axvline(x=high,color='black',linestyle=':',label=f'high: {high:.2f}')
        axs[0,i].set_title(keys[i])
        axs[0,i].legend()
        #axs[0,i].set_xlabel('Predicted - True')
    else:
        pred_err = predictions[:,i]-y_test_rescaled[:,i]
        med = np.median(pred_err)
        low = np.percentile(pred_err,15.9)
        high = np.percentile(pred_err,84.1)
        axs[1,i-4].hist(pred_err,bins=10,color='skyblue')
        axs[1,i-4].axvline(x=med,color='blue',linestyle='--',label=f'median: {med:.2f}')
        axs[1,i-4].axvline(x=low,color='black',linestyle=':',label=f'low: {low:.2f}')
        axs[1,i-4].axvline(x=high,color='black',linestyle=':',label=f'high: {high:.2f}')
        axs[1,i-4].set_title(keys[i])
        axs[1,i-4].legend()
        axs[1,i-4].set_xlabel('Predicted - True')

# %%
y_test_rescaled_1M = scaler.inverse_transform(y_test)
predictions_1M = np.array(pred.cpu())
predictions_1M = scaler.inverse_transform(predictions_1M)

# %%
pred_data = torch.from_numpy(test_planets).float()
with torch.no_grad():
    pred_data = pred_data.to(device)
    pred = net_1m(pred_data)    
pred = np.array(pred.cpu())    
pred = scaler.inverse_transform(pred)
pred
# Out:
# array([[ 1.9977864e+03,  4.7386843e-01, -7.9796085e+00, -8.2273779e+00,
#         -5.2087131e+00, -3.7135606e+00, -4.3925629e+00],
#        [ 1.1188351e+03,  3.4838635e-01, -2.7088749e+00, -2.6995652e+00,
#         -8.3189478e+00, -5.7464828e+00, -5.1073170e+00],
#        [ 2.6594133e+03, -3.5276868e+00, -5.4527526e+00, -5.2090874e+00,
#         -6.0013657e+00, -2.7065215e+00, -5.3153524e+00]], dtype=float32)

# %%
planetA_pred_1M = pred[0]
print("Predicted values:",planetA_pred_1M)
print("Actual values:",planetA_params[3:])
# Out:
# Predicted values: [ 1.9977864e+03  4.7386843e-01 -7.9796085e+00 -8.2273779e+00
#  -5.2087131e+00 -3.7135606e+00 -4.3925629e+00]
# Actual values: [ 2.08383676e+03 -1.94865038e-01 -7.35204337e+00 -8.11423364e+00
#  -5.01872241e+00 -3.65232765e+00 -4.16874130e+00]

# %%
planetB_pred_1M = pred[1]
print("Predicted values:",planetB_pred_1M)
print("Actual values:",planetB_params[3:])
# Out:
# Predicted values: [ 1.1188351e+03  3.4838635e-01 -2.7088749e+00 -2.6995652e+00
#  -8.3189478e+00 -5.7464828e+00 -5.1073170e+00]
# Actual values: [ 1.11335948e+03  1.70457392e-01 -2.78129766e+00 -2.70422089e+00
#  -8.81511155e+00 -5.79890730e+00 -5.21304883e+00]

# %%
planetC_pred_1M = pred[2]
print("Predicted values:",planetC_pred_1M)
print("Actual values:",planetC_params[3:])
# Out:
# Predicted values: [2659.4133      -3.5276868   -5.4527526   -5.2090874   -6.0013657
#    -2.7065215   -5.3153524]
# Actual values: [ 2.66055847e+03 -3.48554752e+00 -5.39606516e+00 -5.07833705e+00
#  -5.97777151e+00 -2.57789940e+00 -5.33643891e+00]

# %% [markdown]
# ## Comparison

# %%
labels1 = ['True']
labels2 = ['10k_pred']
labels3 = ['100k_pred']
labels4 = ['1M_pred']
fig, axs = plt.subplots(2, 4, figsize=(20,10))

for i in range(7):
    if i < 2:
        axs[0,i].bar(labels1, planetA_params[3+i])
        axs[0,i].bar(labels2, planetA_pred_10k[i])
        axs[0,i].bar(labels3, planetA_pred_100k[i])
        axs[0,i].bar(labels4, planetA_pred_1M[i])
        axs[0,i].set_title(keys[i])
        axs[0,i].axhline(y=planetA_params[3+i],color='black', linestyle='--')
        axs[0,0].set_ylim(0.80*planetA_params[3],1.20*planetA_params[3])
    elif i<4 and i>1:
        axs[0,i].bar(labels1, planetA_params[3+i])
        axs[0,i].bar(labels2, planetA_pred_10k[i])
        axs[0,i].bar(labels3, planetA_pred_100k[i])
        axs[0,i].bar(labels4, planetA_pred_1M[i])
        axs[0,i].set_title(keys[i])
        axs[0,i].axhline(y=planetA_params[3+i],color='black', linestyle='--')
        axs[0,i].invert_yaxis()
        axs[0,i].set_ylim(0.80*planetA_params[3+i],1.20*planetA_params[3+i])
    else:
        axs[1,i-4].bar(labels1, planetA_params[3+i])
        axs[1,i-4].bar(labels2, planetA_pred_10k[i])
        axs[1,i-4].bar(labels3, planetA_pred_100k[i])
        axs[1,i-4].bar(labels4, planetA_pred_1M[i])
        axs[1,i-4].set_title(keys[i])
        axs[1,i-4].axhline(y=planetA_params[3+i],color='black', linestyle='--')
        axs[1,i-4].invert_yaxis()
        axs[1,i-4].set_ylim(0.80*planetA_params[3+i],1.20*planetA_params[3+i])
        
plt.savefig('comparison_plot1.png')

# %%
fig, axs = plt.subplots(2, 4, figsize=(20,10))

for i in range(7):
    if i < 2:
        axs[0,i].bar(labels1, planetB_params[3+i])
        axs[0,i].bar(labels2, planetB_pred_10k[i])
        axs[0,i].bar(labels3, planetB_pred_100k[i])
        axs[0,i].bar(labels4, planetB_pred_1M[i])
        axs[0,i].set_title(keys[i])
        axs[0,i].axhline(y=planetB_params[3+i],color='black', linestyle='--')
        axs[0,0].set_ylim(0.80*planetB_params[3],1.20*planetB_params[3])
    elif i<4 and i>1:
        axs[0,i].bar(labels1, planetB_params[3+i])
        axs[0,i].bar(labels2, planetB_pred_10k[i])
        axs[0,i].bar(labels3, planetB_pred_100k[i])
        axs[0,i].bar(labels4, planetB_pred_1M[i])
        axs[0,i].set_title(keys[i])
        axs[0,i].axhline(y=planetB_params[3+i],color='black', linestyle='--')
        axs[0,i].invert_yaxis()
        axs[0,i].set_ylim(0.80*planetB_params[3+i],1.20*planetB_params[3+i])
    else:
        axs[1,i-4].bar(labels1, planetB_params[3+i])
        axs[1,i-4].bar(labels2, planetB_pred_10k[i])
        axs[1,i-4].bar(labels3, planetB_pred_100k[i])
        axs[1,i-4].bar(labels4, planetB_pred_1M[i])
        axs[1,i-4].set_title(keys[i])
        axs[1,i-4].axhline(y=planetB_params[3+i],color='black', linestyle='--')
        axs[1,i-4].invert_yaxis()
        axs[1,i-4].set_ylim(0.80*planetB_params[3+i],1.20*planetB_params[3+i])
        
plt.savefig('comparison_plot2.png')

# %%
fig, axs = plt.subplots(2, 4, figsize=(20,10))
for i in range(7):
    if i < 2:
        axs[0,i].bar(labels1, planetC_params[3+i])
        axs[0,i].bar(labels2, planetC_pred_10k[i])
        axs[0,i].bar(labels3, planetC_pred_100k[i])
        axs[0,i].bar(labels4, planetC_pred_1M[i])
        axs[0,i].set_title(keys[i])
        axs[0,i].axhline(y=planetC_params[3+i],color='black', linestyle='--')
        axs[0,0].set_ylim(0.80*planetC_params[3],1.20*planetC_params[3])
    elif i<4 and i>1:
        axs[0,i].bar(labels1, planetC_params[3+i])
        axs[0,i].bar(labels2, planetC_pred_10k[i])
        axs[0,i].bar(labels3, planetC_pred_100k[i])
        axs[0,i].bar(labels4, planetC_pred_1M[i])
        axs[0,i].set_title(keys[i])
        axs[0,i].axhline(y=planetC_params[3+i],color='black', linestyle='--')
        axs[0,i].invert_yaxis()
        axs[0,i].set_ylim(0.80*planetC_params[3+i],1.20*planetC_params[3+i])
    else:
        axs[1,i-4].bar(labels1, planetC_params[3+i])
        axs[1,i-4].bar(labels2, planetC_pred_10k[i])
        axs[1,i-4].bar(labels3, planetC_pred_100k[i])
        axs[1,i-4].bar(labels4, planetC_pred_1M[i])
        axs[1,i-4].set_title(keys[i])
        axs[1,i-4].axhline(y=planetC_params[3+i],color='black', linestyle='--')
        axs[1,i-4].invert_yaxis()
        axs[1,i-4].set_ylim(0.80*planetC_params[3+i],1.20*planetC_params[3+i])
        
plt.savefig('comparison_plot3.png')

# %% [markdown]
# ## Error histograms

# %%
y_test_rescaled_10k.shape, predictions_10k.shape
# Out:
# ((2000, 7), (2000, 7))

# %%
y_test_rescaled_100k.shape, predictions_100k.shape
# Out:
# ((20000, 7), (20000, 7))

# %%
y_test_rescaled_1M.shape, predictions_1M.shape
# Out:
# ((199195, 7), (199195, 7))

# %%
keys = ['T', 'log_P_cloud', 'log_H2O', 'log_CO2', 'log_CO', 'log_CH4', 'log_NH3']
fig, axs = plt.subplots(2, 4, figsize=(20,10))
for i in range(7):
    if i < 4:
        pred_err_10k = predictions_10k[:,i]-y_test_rescaled_10k[:,i]
        pred_err_100k = predictions_100k[:,i]-y_test_rescaled_100k[:,i]
        pred_err_1M = predictions_1M[:,i]-y_test_rescaled_1M[:,i]
        low_10k, med_10k, high_10k = np.percentile(pred_err_10k,(15.9,50,84.1))
        low_100k, med_100k, high_100k = np.percentile(pred_err_100k,(15.9,50,84.1))
        low_1M, med_1M, high_1M = np.percentile(pred_err_1M,(15.9,50,84.1))
        
        axs[0,i].hist(pred_err_10k,bins=10,color='skyblue',label='10k',density=True)
        axs[0,i].axvline(x=med_10k,color='blue',linestyle='--')
        axs[0,i].axvline(x=low_10k,color='blue',linestyle=':')
        axs[0,i].axvline(x=high_10k,color='blue',linestyle=':')

        axs[0,i].hist(pred_err_100k,bins=10,color='lightgreen',label='100k',density=True,alpha=0.8)
        axs[0,i].axvline(x=med_100k,color='green',linestyle='--')
        axs[0,i].axvline(x=low_100k,color='green',linestyle=':')
        axs[0,i].axvline(x=high_100k,color='green',linestyle=':')

        axs[0,i].hist(pred_err_1M,bins=10,color='orchid',label='1M',density=True,alpha=0.6)
        axs[0,i].axvline(x=med_1M,color='purple',linestyle='--')
        axs[0,i].axvline(x=low_1M,color='purple',linestyle=':')
        axs[0,i].axvline(x=high_1M,color='purple',linestyle=':')
        axs[0,i].set_title(keys[i])
        axs[0,i].legend()
        #axs[0,i].set_xlabel('Predicted - True')
    else:
        pred_err_10k = predictions_10k[:,i]-y_test_rescaled_10k[:,i]
        pred_err_100k = predictions_100k[:,i]-y_test_rescaled_100k[:,i]
        pred_err_1M = predictions_1M[:,i]-y_test_rescaled_1M[:,i]
        low_10k, med_10k, high_10k = np.percentile(pred_err_10k,(15.9,50,84.1))
        low_100k, med_100k, high_100k = np.percentile(pred_err_100k,(15.9,50,84.1))
        low_1M, med_1M, high_1M = np.percentile(pred_err_1M,(15.9,50,84.1))
        
        axs[1,i-4].hist(pred_err_10k,bins=10,color='skyblue',label='10k',density=True)
        axs[1,i-4].axvline(x=med_10k,color='blue',linestyle='--')
        axs[1,i-4].axvline(x=low_10k,color='blue',linestyle=':')
        axs[1,i-4].axvline(x=high_10k,color='blue',linestyle=':')

        axs[1,i-4].hist(pred_err_100k,bins=10,color='lightgreen',label='100k',density=True,alpha=0.8)
        axs[1,i-4].axvline(x=med_100k,color='green',linestyle='--')
        axs[1,i-4].axvline(x=low_100k,color='green',linestyle=':')
        axs[1,i-4].axvline(x=high_100k,color='green',linestyle=':')

        axs[1,i-4].hist(pred_err_1M,bins=10,color='orchid',label='1M',density=True,alpha=0.6)
        axs[1,i-4].axvline(x=med_1M,color='purple',linestyle='--')
        axs[1,i-4].axvline(x=low_1M,color='purple',linestyle=':')
        axs[1,i-4].axvline(x=high_1M,color='purple',linestyle=':')
        axs[1,i-4].set_title(keys[i])
        axs[1,i-4].legend()
        axs[1,i-4].set_xlabel('Predicted - True')
plt.tight_layout()
plt.savefig('error_histograms1.png')

# %%
keys = ['T', 'log_P_cloud', 'log_H2O', 'log_CO2', 'log_CO', 'log_CH4', 'log_NH3']
fig, axs = plt.subplots(2, 4, figsize=(20,10))
for i in range(7):
    if i < 4:
        pred_err_10k = predictions_10k[:,i]-y_test_rescaled_10k[:,i]
        pred_err_100k = predictions_100k[:,i]-y_test_rescaled_100k[:,i]
        pred_err_1M = predictions_1M[:,i]-y_test_rescaled_1M[:,i]
        low_10k, med_10k, high_10k = np.percentile(pred_err_10k,(15.9,50,84.1))
        low_100k, med_100k, high_100k = np.percentile(pred_err_100k,(15.9,50,84.1))
        low_1M, med_1M, high_1M = np.percentile(pred_err_1M,(15.9,50,84.1))
        
        axs[0,i].hist(pred_err_10k,bins=10,color='blue',label='10k',density=True,histtype='step')
    
        axs[0,i].hist(pred_err_100k,bins=10,color='green',label='100k',density=True,histtype='step')
        

        axs[0,i].hist(pred_err_1M,bins=10,color='orchid',label='1M',density=True,histtype='step')

        axs[0,i].set_title(keys[i])
        axs[0,i].legend()
        #axs[0,i].set_xlabel('Predicted - True')
    else:
        pred_err_10k = predictions_10k[:,i]-y_test_rescaled_10k[:,i]
        pred_err_100k = predictions_100k[:,i]-y_test_rescaled_100k[:,i]
        pred_err_1M = predictions_1M[:,i]-y_test_rescaled_1M[:,i]
        low_10k, med_10k, high_10k = np.percentile(pred_err_10k,(15.9,50,84.1))
        low_100k, med_100k, high_100k = np.percentile(pred_err_100k,(15.9,50,84.1))
        low_1M, med_1M, high_1M = np.percentile(pred_err_1M,(15.9,50,84.1))
        
        axs[1,i-4].hist(pred_err_10k,bins=10,color='blue',label='10k',density=True,histtype='step')


        axs[1,i-4].hist(pred_err_100k,bins=10,color='green',label='100k',density=True,histtype='step')


        axs[1,i-4].hist(pred_err_1M,bins=10,color='orchid',label='1M',density=True,histtype='step')

        axs[1,i-4].set_title(keys[i])
        axs[1,i-4].legend()
        axs[1,i-4].set_xlabel('Predicted - True')
plt.tight_layout()
plt.savefig('error_histograms2.png')
